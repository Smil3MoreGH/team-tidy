# %%
#imports
import pandas as pd

# %%
#import the dataset with pandas
df = pd.read_excel('C:/Users/maxil/Desktop/team-tidy/salary/salary_data_states.xlsx')

# %%
#clean the dataset, removing unnecessary columns and NA
df.drop(columns=['PREVAILING_WAGE_SUBMITTED', 'PREVAILING_WAGE_SUBMITTED_UNIT', 'PAID_WAGE_SUBMITTED', 'PAID_WAGE_SUBMITTED_UNIT'])
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
df['EDUCATION_LEVEL_REQUIRED'] = df['EDUCATION_LEVEL_REQUIRED'].fillna("Nothing")
df['COLLEGE_MAJOR_REQUIRED'] = df['COLLEGE_MAJOR_REQUIRED'].fillna("Nothing")
df['EXPERIENCE_REQUIRED_Y_N'] = df['EXPERIENCE_REQUIRED_Y_N'].fillna("n")
df['EXPERIENCE_REQUIRED_NUM_MONTHS'] = df['EXPERIENCE_REQUIRED_NUM_MONTHS'].fillna(0)
df['COUNTRY_OF_CITIZENSHIP'] = df['COUNTRY_OF_CITIZENSHIP'].fillna("Unknown")
df['WORK_POSTAL_CODE'] = df['WORK_POSTAL_CODE'].fillna("Unknown")
df['FULL_TIME_POSITION_Y_N'] = df['FULL_TIME_POSITION_Y_N'].fillna("n")
df['PREVAILING_WAGE_PER_YEAR'] = df['PREVAILING_WAGE_PER_YEAR'].fillna(0)

# %%
df
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...
